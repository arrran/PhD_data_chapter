# %% [markdown]
# for an example of xarray in use https://github.com/weiji14/deepicedrain/blob/atl11_play/atl11_play.ipynb

# %%
import rasterio as rio
import rasterio.mask
import fiona
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon
import numpy as np
import os
import sys
import glob
import matplotlib.pyplot as plt
from scipy import interpolate
import xarray as xr
from shapely.geometry import Point

# %%
path = "/Volumes/arc_02/REMOTE_SENSING/ICESAT2/kamb_atl11_subset.nc"

# %%
ds = xr.open_dataset(path, engine="h5netcdf")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                      (cycle_number: 6, poly_exponent_x: 8, poly_exponent_y: 8, ref_pt: 1512084)
# Coordinates:
#   * cycle_number                 (cycle_number) int64 1 2 3 4 5 6
#   * poly_exponent_x              (poly_exponent_x) int64 1 0 2 1 0 3 2 1
#   * poly_exponent_y              (poly_exponent_y) int64 0 1 0 1 2 0 1 2
#   * ref_pt                       (ref_pt) int64 1533075 1533096 ... 1475760
#     x                            (ref_pt) float64 ...
#     y                            (ref_pt) float64 ...
# Data variables:
#     at_slope                     (ref_pt) float64 ...
#     complex_surface_flag         (ref_pt) float64 ...
#     curvature                    (ref_pt) float64 ...
#     deg_x                        (ref_pt) float64 ...
#     deg_y                        (ref_pt) float64 ...
#     delta_time                   (ref_pt, cycle_number) timedelta64[ns] ...
#     dem_h                        (ref_pt) float64 ...
#     e_slope                      (ref_pt) float64 ...
#     h_corr                       (ref_pt, cycle_number) float64 ...
#     h_corr_sigma                 (ref_pt, cycle_number) float64 ...
#     h_corr_sigma_systematic      (ref_pt, cycle_number) float64 ...
#     latitude                     (ref_pt) float64 ...
#     longitude                    (ref_pt) float64 ...
#     misfit_RMS                   (ref_pt) float64 ...
#     misfit_chi2r                 (ref_pt) float64 ...
#     n_slope                      (ref_pt) float64 ...
#     poly_coeffs                  (ref_pt, poly_exponent_x) float64 ...
#     poly_coeffs_sigma            (ref_pt, poly_exponent_x) float64 ...
#     quality_summary_corrected_h  (ref_pt, cycle_number) float64 ...
#     quality_summary_ref_surf     (ref_pt) float64 ...
#     rgt_azimuth                  (ref_pt) float64 ...
#     slope_change_rate_x          (ref_pt) float64 ...
#     slope_change_rate_x_sigma    (ref_pt) float64 ...
#     slope_change_rate_y          (ref_pt) float64 ...
#     slope_change_rate_y_sigma    (ref_pt) float64 ...
#     utc_time                     (ref_pt, cycle_number) datetime64[ns] ...
#     x_atc                        (ref_pt) float64 ...
#     xt_slope                     (ref_pt) float64 ...
#     y_atc                        (ref_pt) float64 ...
# Attributes:
#     poly_exponent_x:  [1 0 2 1 0 3 2 1]
#     poly_exponent_y:  [0 1 0 1 2 0 1 2]
#     slope_change_t0:  29548800

# %%
df6 = ds.drop_dims(['poly_exponent_x','poly_exponent_y']).sel(cycle_number=6).to_dataframe()

# %%
geometry = [Point(xy) for xy in zip(df6.x, df6.y)]
df6 = gpd.GeoDataFrame(df6, geometry=geometry,crs="EPSG:3031" )

# %%
# Out:
# ref_pt
# 1533075   -411541.944172
# 1533096   -411696.860273
# 1533099   -411718.824339
# 1533114   -411829.371391
# 1533144   -412051.579442
#                ...
# 1475223   -421646.161754
# 1475391   -418673.864145
# 1475745   -412411.580006
# 1475748   -412358.367328
# 1475760   -412145.931245
# Name: x, Length: 1512084, dtype: float64

# %%
# Out:
# ref_pt
# 1533075   NaN
# 1533096   NaN
# 1533099   NaN
# 1533114   NaN
# 1533144   NaN
#            ..
# 1475223   NaN
# 1475391   NaN
# 1475745   NaN
# 1475748   NaN
# 1475760   NaN
# Name: h_corr, Length: 1512084, dtype: float64

# %%
kamb_dataset.isel(cycle_number=0)
# Out:
# <xarray.Dataset>
# Dimensions:                      (poly_exponent_x: 8, poly_exponent_y: 8, ref_pt: 1512084)
# Coordinates:
#   * poly_exponent_x              (poly_exponent_x) int64 1 0 2 1 0 3 2 1
#   * poly_exponent_y              (poly_exponent_y) int64 0 1 0 1 2 0 1 2
#     cycle_number                 int64 1
#   * ref_pt                       (ref_pt) int64 1533075 1533096 ... 1475760
#     x                            (ref_pt) float64 -4.115e+05 ... -4.121e+05
#     y                            (ref_pt) float64 -4.258e+05 ... -4.329e+05
# Data variables:
#     at_slope                     (ref_pt) float64 dask.array<rechunk-merge, s...
#     complex_surface_flag         (ref_pt) float64 dask.array<rechunk-merge, s...
#     curvature                    (ref_pt) float64 dask.array<rechunk-merge, s...
#     deg_x                        (ref_pt) float64 dask.array<rechunk-merge, s...
#     deg_y                        (ref_pt) float64 dask.array<rechunk-merge, s...
#     delta_time                   (ref_pt) timedelta64[ns] dask.array<getitem,...
#     dem_h                        (ref_pt) float64 dask.array<rechunk-merge, s...
#     e_slope                      (ref_pt) float64 dask.array<rechunk-merge, s...
#     h_corr                       (ref_pt) float64 dask.array<getitem, shape=(...
#     h_corr_sigma                 (ref_pt) float64 dask.array<getitem, shape=(...
#     h_corr_sigma_systematic      (ref_pt) float64 dask.array<getitem, shape=(...
#     latitude                     (ref_pt) float64 dask.array<rechunk-merge, s...
#     longitude                    (ref_pt) float64 dask.array<rechunk-merge, s...
#     misfit_RMS                   (ref_pt) float64 dask.array<rechunk-merge, s...
#     misfit_chi2r                 (ref_pt) float64 dask.array<rechunk-merge, s...
#     n_slope                      (ref_pt) float64 dask.array<rechunk-merge, s...
#     poly_coeffs                  (ref_pt, poly_exponent_x) float64 dask.array...
#     poly_coeffs_sigma            (ref_pt, poly_exponent_x) float64 dask.array...
#     quality_summary_corrected_h  (ref_pt) float64 dask.array<getitem, shape=(...
#     quality_summary_ref_surf     (ref_pt) float64 dask.array<rechunk-merge, s...
#     rgt_azimuth                  (ref_pt) float64 dask.array<rechunk-merge, s...
#     slope_change_rate_x          (ref_pt) float64 dask.array<rechunk-merge, s...
#     slope_change_rate_x_sigma    (ref_pt) float64 dask.array<rechunk-merge, s...
#     slope_change_rate_y          (ref_pt) float64 dask.array<rechunk-merge, s...
#     slope_change_rate_y_sigma    (ref_pt) float64 dask.array<rechunk-merge, s...
#     x_atc                        (ref_pt) float64 dask.array<rechunk-merge, s...
#     xt_slope                     (ref_pt) float64 dask.array<rechunk-merge, s...
#     y_atc                        (ref_pt) float64 dask.array<rechunk-merge, s...
#     utc_time                     (ref_pt) datetime64[ns] NaT ... 2018-11-27T09:07:11.892510831
# Attributes:
#     poly_exponent_x:  [1, 0, 2, 1, 0, 3, 2, 1]
#     poly_exponent_y:  [0, 1, 0, 1, 2, 0, 1, 2]
#     slope_change_t0:  29548800

# %%
# Convention for import to get shortened namespace
import numpy as np
import xarray as xr

# Create some sample "temperature" data
data = 283 + 5 * np.random.randn(5, 3, 4)
data
# Out:
# array([[[286.01978843, 280.41866042, 286.39948574, 285.77030043],
#         [279.28119139, 281.88808899, 275.73558506, 280.22772467],
#         [290.34090603, 285.5696655 , 284.62658583, 278.08145282]],
#
#        [[283.96882973, 285.52884397, 285.19757622, 280.01366947],
#         [282.48331045, 279.11150541, 278.9426567 , 280.86160717],
#         [270.68944199, 283.75915338, 293.51426502, 282.42491709]],
#
#        [[283.65256871, 275.63106705, 286.51520868, 280.8904092 ],
#         [271.54022417, 272.95353947, 282.02736681, 281.97422228],
#         [283.49306876, 280.86064253, 287.28009572, 284.4680849 ]],
#
#        [[283.9027101 , 287.86121232, 280.30405846, 286.65615436],
#         [277.14298157, 281.95718377, 288.57257721, 278.92912523],
#         [281.71631387, 278.53623993, 277.76227027, 288.04179377]],
#
#        [[289.94025106, 288.44528399, 278.63153227, 281.8701529 ],
#         [287.1421786 , 288.79251451, 284.13808969, 272.67727855],
#         [275.68010775, 283.51670855, 290.21906126, 272.87127144]]])

# %%
temp = xr.DataArray(data)
temp

# %%
temp = xr.DataArray(data, dims=['time', 'lat', 'lon'])
temp
# Out:
# <xarray.DataArray (time: 5, lat: 3, lon: 4)>
# array([[[286.01978843, 280.41866042, 286.39948574, 285.77030043],
#         [279.28119139, 281.88808899, 275.73558506, 280.22772467],
#         [290.34090603, 285.5696655 , 284.62658583, 278.08145282]],
#
#        [[283.96882973, 285.52884397, 285.19757622, 280.01366947],
#         [282.48331045, 279.11150541, 278.9426567 , 280.86160717],
#         [270.68944199, 283.75915338, 293.51426502, 282.42491709]],
#
#        [[283.65256871, 275.63106705, 286.51520868, 280.8904092 ],
#         [271.54022417, 272.95353947, 282.02736681, 281.97422228],
#         [283.49306876, 280.86064253, 287.28009572, 284.4680849 ]],
#
#        [[283.9027101 , 287.86121232, 280.30405846, 286.65615436],
#         [277.14298157, 281.95718377, 288.57257721, 278.92912523],
#         [281.71631387, 278.53623993, 277.76227027, 288.04179377]],
#
#        [[289.94025106, 288.44528399, 278.63153227, 281.8701529 ],
#         [287.1421786 , 288.79251451, 284.13808969, 272.67727855],
#         [275.68010775, 283.51670855, 290.21906126, 272.87127144]]])
# Dimensions without coordinates: time, lat, lon

# %%
temp.isel(time=0)
# Out:
# <xarray.DataArray (lat: 3, lon: 4)>
# array([[286.01978843, 280.41866042, 286.39948574, 285.77030043],
#        [279.28119139, 281.88808899, 275.73558506, 280.22772467],
#        [290.34090603, 285.5696655 , 284.62658583, 278.08145282]])
# Dimensions without coordinates: lat, lon

# %%
x=1
