# %%
import h5py
import xarray as xr

# %%
path = '/Volumes/arc_01/horganhu/ICESAT/GLA12_633_TRACKS/track1275_processed.mat'
# track1 = '/Volumes/arc_01/horganhu/ICESAT/GLA12_633_TRACKS/track1275_processed.mat'

# %%
with h5py.File(path, 'r') as f:
    gs = list(f.keys())
    print(gs)
    for g in gs:
        print(g,': ',list(f[g].keys()))
        hs = list(f[g].keys())
        for h in hs:
            print(h,': ',list(f[g][h].keys()))
#             js = list(f[g][h].keys())
#             for j in js:
#                 print(j,': ',list(f[g][h][j].keys()))
# Out:
# ['antarctica']
# antarctica :  ['track1331']
# track1331 :  ['DEMhiresArElv', 'DEMhiresGradX', 'DEMhiresGradY', 'IceSVar', 'Surface_pres', 'UTCTime', 'delta_h', 'ecefx', 'ecefy', 'ecefz', 'elev', 'elev_wgs84_retide', 'elev_wgs84_tpxtide', 'elev_wgs84_tpxtide_ibe', 'gdHT', 'gval_rcv', 'ibe', 'lat', 'ldElv', 'lon', 'ocElv', 'psx', 'psy', 'rec_ndx', 'reflCor', 'reflctUC', 'satCorrFlg', 'satElevCorr', 'sdatedays', 'tpxo62_load', 'tpxo71_z']

# %% [markdown]
# - 'DEMhiresArElv',
# - 'DEMhiresGradX',
# - 'DEMhiresGradY',
# - 'IceSVar',
# - 'Surface_pres',
# - 'UTCTime',
# - 'delta_h',
# - 'ecefx',
# - 'ecefy',
# - 'ecefz',
# - 'elev',
# - 'elev_wgs84_retide', Retide is huws tide correction done
# - 'elev_wgs84_tpxtide',
# - 'elev_wgs84_tpxtide_ibe',
# - 'gdHT',
# - 'gval_rcv',
# - 'ibe',
# - 'lat',
# - 'ldElv', '
# - lon',
# - 'ocElv',
# - 'psx',
# - 'psy',
# - 'rec_ndx',
# - 'reflCor',
# - 'reflctUC',
# - 'satCorrFlg',
# - 'satElevCorr',
# - 'sdatedays',
# - 'tpxo62_load',
# - 'tpxo71_z'

# %%
def icesat1todataframe(track):
    """
    track = eg 'track1275'
    """
    
    
    
    path = f'/Volumes/arc_01/horganhu/ICESAT/GLA12_633_TRACKS/{track1275}_processed.mat'
    df = pd.DataFrame({'x':[],
                       'pass':[],
                      })
    psys = []
    h = []
    time = []
    dh = []

    with h5py.File(path, 'r') as f:
        #add x location
        psx_l = list(f['antarctica']['track1275']['psx'])
        for p in psx_l:
            df_temp = pd.DataFrame({'x': list(f['antarctica']['track1275']['psx'][p][0]),
                                    'pass': [p]*len(list(f['antarctica']['track1275']['psx'][p])[0]) })
            df = df.append(df_temp , ignore_index=True )

        #add y location
        psy_l = list(f['antarctica']['track1275']['psy'])
        for p in psy_l:
            psys.extend( list(f['antarctica']['track1275']['psy'][p][0]) )

        #add height
        h_l = list(f['antarctica']['track1275']['elev_wgs84_retide'])
        for p in h_l:
            h.extend( list(f['antarctica']['track1275']['elev_wgs84_retide'][p][0]) )

        #add time
        t_l = list(f['antarctica']['track1275']['UTCTime'])
        for p in t_l:
            time.extend( list(f['antarctica']['track1275']['UTCTime'][p][0]) )

        #add delta_h (not sure what it is)
        dh_l = list(f['antarctica']['track1275']['delta_h'])
        for p in dh_l:
            dh.extend( list(f['antarctica']['track1275']['delta_h'][p][0]) )

    df['y'] = psys
    df['h'] = h
    df['time'] = time
    df['delta_h'] = dh

    da = df.query("x > -382064.5722209641 & x < -374781.1654740692 & y > -734075.0820404041 & y < -722764.4514729496")
    da.reset_index(drop=True,inplace=True)
    return da
# Out:
#                 x       pass              y          h          time   delta_h
# 0  -378379.052847  psxPass23 -722784.147169  57.016596  2.909264e+08 -0.709404
# 1  -378364.951877  psxPass23 -722952.228756  57.220502  2.909264e+08 -0.700498
# 2  -378350.970028  psxPass23 -723120.483199  57.193273  2.909264e+08 -0.704727
# 3  -378336.854504  psxPass23 -723288.550248  57.319653  2.909264e+08 -0.713347
# 4  -378322.744411  psxPass23 -723456.726506  57.483273  2.909264e+08 -0.708727
# ..            ...        ...            ...        ...           ...       ...
# 63 -377468.102628  psxPass23 -733366.527022  32.786010  2.909264e+08 -0.712990
# 64 -377453.213584  psxPass23 -733534.327877  32.555158  2.909264e+08 -0.703842
# 65 -377438.393637  psxPass23 -733702.205074  32.619199  2.909264e+08 -0.700801
# 66 -377423.580079  psxPass23 -733870.068184  32.520739  2.909264e+08 -0.710261
# 67 -377408.807309  psxPass23 -734038.267597  31.865768  2.909264e+08 -0.712232
#
# [68 rows x 6 columns]

# %%
# Out:
#                 x       pass              y          h
# 0  -378379.052847  psxPass23 -722784.147169  57.016596
# 1  -378364.951877  psxPass23 -722952.228756  57.220502
# 2  -378350.970028  psxPass23 -723120.483199  57.193273
# 3  -378336.854504  psxPass23 -723288.550248  57.319653
# 4  -378322.744411  psxPass23 -723456.726506  57.483273
# ..            ...        ...            ...        ...
# 63 -377468.102628  psxPass23 -733366.527022  32.786010
# 64 -377453.213584  psxPass23 -733534.327877  32.555158
# 65 -377438.393637  psxPass23 -733702.205074  32.619199
# 66 -377423.580079  psxPass23 -733870.068184  32.520739
# 67 -377408.807309  psxPass23 -734038.267597  31.865768
#
# [68 rows x 4 columns]

# %%
psys
# Out:
# [[2109393.7507764995,
#   2109238.077943452,
#   2109082.4718060554,
#   2108926.738828865,
#   2108770.8625798197,
#   2108615.077731133,
#   2108459.1496368777,
#   2108303.2120706695,
#   2108147.1559271985,
#   2107991.114960554,
#   2107834.996478387,
#   2107678.78404341,
#   2107522.594966843,
#   2107366.421028702,
#   2107210.2540142178,
#   2107054.001222081,
#   2106897.7881586095,
#   2106741.6148042646,
#   2106585.513946709,
#   2106429.351840128,
#   2106273.221171435,
#   2106117.1137270126,
#   2105961.247712615,
#   2105805.4048987273,
#   2105649.6698007053,
#   2105493.9415023956,
#   2105338.219999927,
#   2105182.589828534,
#   2105027.0428077057,
#   2104871.570762209,
#   2104716.258258889,
#   2104560.9034773787,
#   2104405.6155460468,
#   2104250.18444951,
#   2104094.7111314973,
#   2103939.1956116883,
#   2103783.436049036,
#   2103627.6424955367,
#   2103471.6049257065,
#   2103315.331525743,
#   2103159.1496284525,
#   2103002.9501333954,
# ...

# %%
a = [33]
a.extend([1,2])
a
# Out:
# [33, 1, 2]

# %%
path = '/Volumes/arc_01/horganhu/ICESAT/GLA12_633_TRACKS/track1331_tracksorted.mat'
with h5py.File(path, 'r') as f:
    gs = list(f.keys())
    print(gs)
    for g in gs:
        print(g,': ',list(f[g].keys()))
        hs = list(f[g].keys())
        for h in hs:
            print(h,': ',list(f[g][h].keys()))
#             js = list(f[g][h].keys())
#             for j in js:
#                 print(j,': ',list(f[g][h][j].keys()))
# Out:
# ['dataStruct']
# dataStruct :  ['track1331']
# track1331 :  ['GLA12_633_2103_001_1331_0_01_0001', 'GLA12_633_2107_001_1331_0_01_0001', 'GLA12_633_2107_002_1331_0_01_0001', 'GLA12_633_2109_001_1331_0_02_0001', 'GLA12_633_2111_001_1331_0_01_0001', 'GLA12_633_2111_002_1331_0_01_0001', 'GLA12_633_2113_001_1331_0_01_0001', 'GLA12_633_2115_001_1331_0_01_0001', 'GLA12_633_2115_002_1331_0_01_0001', 'GLA12_633_2117_001_1331_0_01_0001', 'GLA12_633_2119_001_1331_0_01_0001', 'GLA12_633_2121_001_1331_0_01_0001', 'GLA12_633_2123_001_1331_0_01_0001', 'GLA12_633_2125_001_1331_0_01_0001', 'GLA12_633_2129_001_1331_0_01_0001', 'GLA12_633_2131_001_1331_0_01_0001']

# %%
for o in obj:
#     print(o.split()[0])
    print(o.split()[0].split('/')[1:])
# Out:
# ['']
# ['antarctica']
# ['antarctica', 'track1331']
# ['antarctica', 'track1331', 'DEMhiresArElv']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass1']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass10']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass11']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass12']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass13']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass14']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass15']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass16']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass17']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass18']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass19']
# ['antarctica', 'track1331', 'DEMhiresArElv', 'DEMhiresArElvPass2']
# ...

# %%
for o in obj:
    print(o.split()[0])
#     print(o.split()[0].split('/')[1:])
# Out:
# /
# /antarctica
# /antarctica/track1331
# /antarctica/track1331/DEMhiresArElv
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass1
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass10
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass11
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass12
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass13
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass14
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass15
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass16
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass17
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass18
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass19
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass2
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass20
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass21
# /antarctica/track1331/DEMhiresArElv/DEMhiresArElvPass22
# ...

# %%
psx['psxPass1'][0].min()
# Out:
# -1828903.1190699642

# %%
import pandas as pd

pd.read_hdf(path,'/antarctica/track1331/psx/psxPass1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-a51f976137b6> in <module>
#       1 import pandas as pd
#       2
# ----> 3 pd.read_hdf(path,'/antarctica/track1331/psx/psxPass1')
#
# ~/miniconda3/envs/remote_sensing/lib/python3.7/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     426             iterator=iterator,
#     427             chunksize=chunksize,
# --> 428             auto_close=auto_close,
#     429         )
#     430     except (ValueError, TypeError, KeyError):
#
# ~/miniconda3/envs/remote_sensing/lib/python3.7/site-packages/pandas/io/pytables.py in select(self, key, where, start, stop, columns, iterator, chunksize, auto_close)
#     791         # create the storer and axes
#     792         where = _ensure_term(where, scope_level=1)
# ...
