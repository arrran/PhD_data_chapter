# %% [markdown]
# # Checking radar line cross points

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import sys
import time
import datetime as dt
import pandas as pd
import geopandas as gpd
import scipy as sp
from scipy import signal
from tqdm.notebook import tqdm

from shapely.geometry import Point, LineString, Polygon
import fiona

# %%
bed_gdf = gpd.read_file('/Volumes/arc_04/FIELD_DATA/K8621920/RES/PROCESSED_LINES/picked_bed.shp')

# %%
bed_gdf.head()
# Out:
#    CDP         x         y DELAY line_name  SEQnum  camp  \
# 0  100 -381564.6 -725999.7  8790     line7       1  KIS2
# 1  101 -381563.4 -725998.3  8790     line7       1  KIS2
# 2  102 -381561.6 -725996.1  8790     line7       1  KIS2
# 3  103 -381559.5 -725993.6  8790     line7       1  KIS2
# 4  104 -381557.4 -725991.1  8790     line7       1  KIS2
#
#                           geometry
# 0  POINT (-381564.600 -725999.700)
# 1  POINT (-381563.400 -725998.300)
# 2  POINT (-381561.600 -725996.100)
# 3  POINT (-381559.500 -725993.600)
# 4  POINT (-381557.400 -725991.100)

# %% [markdown]
# # Looping over shapely intersections is too slow, so we use gdf.query
#
# this give us a list of lists. For each point there is nan if no points are close or a list of CDPs of close points

# %%
other_points = []

buffer_size = 20.0

for i in tqdm(range(bed_gdf.shape[0])):

    other_points.append( bed_gdf.query(f'line_name != "{bed_gdf.line_name.loc[i]}" & camp == "{bed_gdf.camp.loc[i]}" & x > {bed_gdf.x.loc[i] - buffer_size} & x < {bed_gdf.x.loc[i] + buffer_size} & y > {bed_gdf.y.loc[i] - buffer_size} & y < {bed_gdf.y.loc[i] + buffer_size}').CDP.tolist() )    
    
#print(f'line_name != "{bed_gdf.line_name.loc[i]}" & camp == "{bed_gdf.camp.loc[i]}" & x > {bed_gdf.x.loc[i] - buffer_size} & x < {bed_gdf.x.loc[i] + buffer_size} & y > {bed_gdf.y.loc[i] - buffer_size} & y < {bed_gdf.y.loc[i] + buffer_size}')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=78355.0), HTML(value='')))

# %%
op = []
for i, close_points in enumerate(other_points):
    if close_points==[]:
        op.append(np.nan)
    else:
        op.append([int(p) for p in close_points])

# %%
bed_gdf['close_points_20m'] = op

# %%
bed_gdf.dropna()
# Out:
#        CDP         x         y DELAY line_name  SEQnum  camp  \
# 376    476 -380809.2 -725164.3  8620     line7       1  KIS2
# 377    477 -380807.5 -725162.7  8620     line7       1  KIS2
# 378    478 -380805.8 -725161.3  8620     line7       1  KIS2
# 379    479 -380802.4 -725158.6  8620     line7       1  KIS2
# 380    480 -380800.7 -725157.1  8620     line7       1  KIS2
# ...    ...       ...       ...   ...       ...     ...   ...
# 77697  964 -379157.2 -726682.4  7458     line5      49  KIS2
# 77698  965 -379159.4 -726684.9  7469     line5      49  KIS2
# 77699  966 -379160.4 -726686.0  7480     line5      49  KIS2
# 77700  967 -379162.6 -726688.6  7492     line5      49  KIS2
# 77701  968 -379164.8 -726691.1  7503     line5      49  KIS2
#
#                               geometry  \
# 376    POINT (-380809.200 -725164.300)
# 377    POINT (-380807.500 -725162.700)
# 378    POINT (-380805.800 -725161.300)
# 379    POINT (-380802.400 -725158.600)
# 380    POINT (-380800.700 -725157.100)
# ...                                ...
# 77697  POINT (-379157.200 -726682.400)
# 77698  POINT (-379159.400 -726684.900)
# 77699  POINT (-379160.400 -726686.000)
# 77700  POINT (-379162.600 -726688.600)
# 77701  POINT (-379164.800 -726691.100)
#
#                                         close_points_20m
# 376                                           [506, 507]
# 377                                 [505, 506, 507, 508]
# 378                       [504, 505, 506, 507, 508, 509]
# 379             [503, 504, 505, 506, 507, 508, 509, 510]
# 380    [502, 503, 504, 505, 506, 507, 508, 509, 510, ...
# ...                                                  ...
# 77697      [845, 846, 847, 848, 849, 850, 851, 852, 853]
# 77698                [846, 847, 848, 849, 850, 851, 852]
# 77699                          [847, 848, 849, 850, 851]
# 77700                                    [847, 848, 849]
# 77701                                              [849]
#
# [3361 rows x 9 columns]

# %%
bed_gdf.to_pickle('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/bed_gdf_close_points_20m.pkl')

# %% [markdown]
# # We now have the list of lists
#
# 1. Next we need to drop any close points that are consecutive.
# 2. Then...

# %%
bed_gdf_ = pd.read_pickle('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/bed_gdf_close_points_20m.pkl')

# %%
cp = bed_gdf.close_points_20m.tolist() #the list of close points

# %%
cp_new = []

for i in tqdm(range(len(cp))):
# for i in tqdm(range(400)):

    if bed_gdf.close_points_20m.isna().loc[i]:
        cp_new.append(np.nan)
        continue
    else:
        point = bed_gdf.close_points_20m.loc[i]
        split_at = np.argwhere(np.diff(np.array(point)) != 1 ).flatten() + 1
        list_of_points_sections = np.split(point, split_at)
        points_output = []
        for points_section in list_of_points_sections:
            points_output.append( int(np.median(points_section)) )
        cp_new.append(points_output)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=78355.0), HTML(value='')))

# %%
cp_new

# %%
# this time making cps close points with no vertical double ups, and including the CDP from original point.

prev_point = 0

for i, row in bed_gdf.iterrows():
    
    if prev_point == row.close_points_20m:
        cps = np.nan
    else:
        cps = [int(row.CDP)] + row.close_points_20m
    
    prev_point = int(row.close_points_20m)
# Out:
#        CDP         x         y DELAY line_name  SEQnum  camp  \
# 376    476 -380809.2 -725164.3  8620     line7       1  KIS2
# 377    477 -380807.5 -725162.7  8620     line7       1  KIS2
# 378    478 -380805.8 -725161.3  8620     line7       1  KIS2
# 379    479 -380802.4 -725158.6  8620     line7       1  KIS2
# 380    480 -380800.7 -725157.1  8620     line7       1  KIS2
# ...    ...       ...       ...   ...       ...     ...   ...
# 77697  964 -379157.2 -726682.4  7458     line5      49  KIS2
# 77698  965 -379159.4 -726684.9  7469     line5      49  KIS2
# 77699  966 -379160.4 -726686.0  7480     line5      49  KIS2
# 77700  967 -379162.6 -726688.6  7492     line5      49  KIS2
# 77701  968 -379164.8 -726691.1  7503     line5      49  KIS2
#
#                               geometry close_points_20m
# 376    POINT (-380809.200 -725164.300)            [506]
# 377    POINT (-380807.500 -725162.700)            [506]
# 378    POINT (-380805.800 -725161.300)            [506]
# 379    POINT (-380802.400 -725158.600)            [506]
# 380    POINT (-380800.700 -725157.100)            [506]
# ...                                ...              ...
# 77697  POINT (-379157.200 -726682.400)            [849]
# 77698  POINT (-379159.400 -726684.900)            [849]
# 77699  POINT (-379160.400 -726686.000)            [849]
# 77700  POINT (-379162.600 -726688.600)            [848]
# 77701  POINT (-379164.800 -726691.100)            [849]
#
# [3361 rows x 9 columns]

# %%
int(bed_gdf.iloc[0].CDP)
# Out:
# 100

# %%
point = bed_gdf.close_points_20m.loc[i]
split_at = np.argwhere(np.diff(np.array(point)) != 1 ).flatten() + 1
list_of_points_sections = np.split(point, split_at)
points_output = []
for points_section in list_of_points_sections:
    points_output.append( int(np.median(points_section)) )
points_output
# Out:
# [507]

# %%
split_at = np.argwhere(np.diff(np.array(point)) != 1 ).flatten() + 1
split_at
# Out:
# array([], dtype=int64)

# %%
point_output = np.split(point, split_at)
point_output
# Out:
# [array([506, 507])]

# %%
cp_new = []

for i in tqdm(range(len(cp))):

    if bed_gdf.close_points_20m.isna().loc[i]:
        cp_new.append(np.nan)
        continue
    else:
        print(i)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=78355.0), HTML(value='')))
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# 431
# 432
# 433
# 434
# 1244
# 1245
# 1246
# 1247
# 1248
# 1255
# 1256
# 1257
# 1258
# 1259
# 1260
# 1261
# 1302
# 1303
# 1304
# 1305
# 1306
# 1307
# 1308
# 1309
# 1310
# 1311
# 1312
# 1313
# 1314
# 1315
# 1316
# 1317
# 1318
# 1319
# 2279
# 2280
# 2281
# 2282
# 2283
# 2284
# 2285
# 2286
# 2287
# 2288
# 2289
# 2290
# 2291
# 2292
# 2293
# 2294
# 2295
# 2296
# 2297
# 2783
# 2784
# 2785
# 2786
# 2787
# 2788
# 2789
# 2790
# 2791
# 2792
# 2793
# 3498
# 3499
# 3500
# 3501
# 3502
# 3503
# 3504
# 3505
# 3506
# 3507
# 3508
# 3509
# 3510
# 3511
# 3512
# 3513
# 3514
# 3515
# 4173
# 4174
# 4175
# 4176
# 4177
# 4178
# 4179
# 4761
# 4762
# 4763
# 4764
# 4765
# 4766
# 4767
# 4768
# 4769
# 4770
# 4771
# 4772
# 4773
# 4774
# 4775
# 4776
# 4777
# 4778
# 5735
# 5736
# 5737
# 5738
# 5739
# 5740
# 5741
# 5745
# 5746
# 5747
# 5748
# 5749
# 5750
# 5751
# 5752
# 5753
# 5754
# 6748
# 6749
# 6750
# 6751
# 6752
# 6753
# 6754
# 6755
# 6756
# 6757
# 6758
# 6759
# 6760
# 6761
# 6762
# 6763
# 6764
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-5d227ea7681f> in <module>
#       3 for i in tqdm(range(len(cp))):
#       4
# ----> 5     if bed_gdf.close_points_20m.isna().loc[i]:
#       6         cp_new.append(np.nan)
#       7         continue
#
# ~/miniconda3/envs/remote_sensing/lib/python3.7/site-packages/pandas/core/series.py in isna(self)
#    4400     @Appender(generic._shared_docs["isna"] % _shared_doc_kwargs)
#    4401     def isna(self):
# -> 4402         return super().isna()
#    4403
#    4404     @Appender(generic._shared_docs["isna"] % _shared_doc_kwargs)
#
# ~/miniconda3/envs/remote_sensing/lib/python3.7/site-packages/pandas/core/generic.py in isna(self)
#    7264     @Appender(_shared_docs["isna"] % _shared_doc_kwargs)
#    7265     def isna(self: FrameOrSeries) -> FrameOrSeries:
# -> 7266         return isna(self).__finalize__(self)
#    7267
#    7268     @Appender(_shared_docs["isna"] % _shared_doc_kwargs)
#
# ~/miniconda3/envs/remote_sensing/lib/python3.7/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     124     Name: 1, dtype: bool
#     125     """
# --> 126     return _isna(obj)
#     127
#     128
#
# ~/miniconda3/envs/remote_sensing/lib/python3.7/site-packages/pandas/core/dtypes/missing.py in _isna_new(obj)
#     150         ),
#     151     ):
# --> 152         return _isna_ndarraylike(obj)
#     153     elif isinstance(obj, ABCGeneric):
#     154         return obj._constructor(obj._data.isna(func=isna))
#
# ~/miniconda3/envs/remote_sensing/lib/python3.7/site-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj)
#     253             # object array of non-strings
#     254             result = np.empty(shape, dtype=bool)
# --> 255             vec = libmissing.isnaobj(values.ravel())
#     256             result[...] = vec.reshape(shape)
#     257
#
# KeyboardInterrupt:

# %%
cp_new
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  [array([506, 507])],
#  [array([505, 506, 507, 508])],
#  [array([504, 505, 506, 507, 508, 509])],
#  [array([503, 504, 505, 506, 507, 508, 509, 510])],
#  [array([502, 503, 504, 505, 506, 507, 508, 509, 510, 511])],
#  [array([501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512])],
#  [array([500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512,
#          513])],
#  [array([499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511,
#          512, 513, 514])],
#  [array([498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510,
#          511, 512, 513, 514, 515, 516])],
#  [array([500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512,
#          513, 514, 515, 516])],
#  [array([500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512,
#          513, 514, 515])],
#  [array([502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513])],
#  [array([502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513])],
#  [array([503, 504, 505, 506, 507, 508, 509, 510, 511, 512])],
#  [array([504, 505, 506, 507, 508, 509, 510])],
#  [array([505, 506, 507, 508, 509, 510])],
#  [array([507, 508])],
#  [array([508])],
#  nan,
#  nan,
#  nan,
#  [array([111, 112])],
#  [array([111, 112, 113])],
#  [array([110, 111, 112, 113, 114, 115])],
#  [array([109, 110, 111, 112, 113, 114, 115, 116])],
#  [array([108, 109, 110, 111, 112, 113, 114, 115, 116, 117])],
#  [array([107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119])],
#  [array([107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119,
#          120])],
#  [array([106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118,
#          119, 120])],
#  [array([106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118,
#          119])],
#  [array([105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117,
#          118])],
#  [array([104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116,
#          117])],
#  [array([103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115,
#          116])],
#  [array([102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114,
#          115])],
#  [array([102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114])],
#  [array([101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113,
#          114])],
#  [array([103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113])],
#  [array([106, 107, 108, 109, 110, 111, 112])],
#  [array([108, 109, 110, 111, 112])],
#  [array([111])],
#  nan,
#  nan,
#  nan,
#  [array([100, 101])],
#  [array([100, 101])],
#  [array([100, 101, 102, 103])],
#  [array([100, 101, 102, 103, 104])],
#  [array([100, 101, 102, 103, 104, 105])],
#  [array([100, 101, 102, 103, 104, 105, 106])],
#  [array([100, 101, 102, 103, 104, 105, 106, 107])],
#  [array([100, 101, 102, 103, 104, 105, 106, 107, 108])],
#  [array([100, 101, 102, 103, 104, 105, 106, 107])],
#  [array([100, 101, 102, 103, 104, 105, 106])],
#  [array([100, 101, 102, 103, 104, 105])],
#  [array([100, 101, 102, 103, 104])],
#  [array([100, 101, 102, 103])],
#  [array([100, 101, 102])],
#  [array([100, 101, 102])],
#  [array([100, 101])],
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
np.diff(np.array(point))

# %%
lines_gdf.set_index('line_names',inplace=True)
lines_gdf.head()

# %%
for line0 in lines_gdf.index.tolist():
    for line1 in lines_gdf.index.tolist():
        if line0.intersects(line1):
            isect_pnt = first.intersection(second)

# %%
lines_gdf.index.tolist()
