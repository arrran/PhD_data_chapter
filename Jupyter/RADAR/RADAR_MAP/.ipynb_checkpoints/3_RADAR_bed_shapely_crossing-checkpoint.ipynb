# %% [markdown]
# # Checking radar line cross points
#
#
# this time with the shapely intersection function

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import sys
import time
import datetime as dt
import pandas as pd
import geopandas as gpd
import scipy as sp
from scipy import signal
from tqdm.notebook import tqdm

from shapely.geometry import Point, LineString, Polygon, MultiPoint
import fiona
from shapely.ops import nearest_points

# %%
bed_gdf = gpd.read_file('/Volumes/arc_04/FIELD_DATA/K8621920/RES/PROCESSED_LINES/picked_bed.shp')

# %%
bed_gdf.head()
# Out:
#    CDP         x         y DELAY line_name  SEQnum  camp  \
# 0  100 -381564.6 -725999.7  8790     line7       1  KIS2
# 1  101 -381563.4 -725998.3  8790     line7       1  KIS2
# 2  102 -381561.6 -725996.1  8790     line7       1  KIS2
# 3  103 -381559.5 -725993.6  8790     line7       1  KIS2
# 4  104 -381557.4 -725991.1  8790     line7       1  KIS2
#
#                           geometry
# 0  POINT (-381564.600 -725999.700)
# 1  POINT (-381563.400 -725998.300)
# 2  POINT (-381561.600 -725996.100)
# 3  POINT (-381559.500 -725993.600)
# 4  POINT (-381557.400 -725991.100)

# %% [markdown]
# # Convert all lines to a shapely LineString

# %%
linestrings = []
names = []

for line_name in bed_gdf.line_name.unique():
    linestrings.append( LineString(bed_gdf[bed_gdf.line_name==line_name].geometry.tolist() ) )
    names.append(line_name)
#put the lines in a geodataframe
lines_gdf = gpd.GeoDataFrame({'line_name':names},geometry=linestrings)
lines_gdf.set_index('line_name',inplace=True)
lines_gdf.head()
# Out:
#                                                     geometry
# line_name
# line7      LINESTRING (-381564.600 -725999.700, -381563.4...
# line9      LINESTRING (-380741.900 -721788.100, -380743.5...
# line0      LINESTRING (-377572.000 -734075.100, -377571.8...
# line10     LINESTRING (-385757.300 -724442.800, -385756.3...
# line11     LINESTRING (-384056.400 -720106.700, -384057.5...

# %% [markdown]
# # Convert all lines to a shapely MultiPoint

# %%
multipoints = []
names_m = []

for line_name in bed_gdf.line_name.unique():
    multipoints.append( MultiPoint(bed_gdf[bed_gdf.line_name==line_name].geometry.tolist() ) )
    names_m.append(line_name)
#put the lines in a geodataframe, lines_mtp multipoint
lines_mtp = gpd.GeoDataFrame({'line_name':names},geometry=multipoints)
lines_mtp.set_index('line_name',inplace=True)
lines_mtp.head()
# Out:
#                                                     geometry
# line_name
# line7      MULTIPOINT (-381564.600 -725999.700, -381563.4...
# line9      MULTIPOINT (-380741.900 -721788.100, -380743.5...
# line0      MULTIPOINT (-377572.000 -734075.100, -377571.8...
# line10     MULTIPOINT (-385757.300 -724442.800, -385756.3...
# line11     MULTIPOINT (-384056.400 -720106.700, -384057.5...

# %%
lines_gdf.index

# %%
line0s = []
line1s = []
intersection_point=[]

for line_name in lines_gdf.index.tolist():
    
    if not lines_gdf.loc['line6'].geometry.intersects(lines_gdf.loc['lineAPRESdown'].geometry)

# %%
lines_gdf.loc['line6'].intersects(lines_gdf.'lineapresdownchan'].geometry)

# %%
intersection_table = pd.DataFrame({})

for line_name in lines_gdf.index.tolist():

    intersection_table[line_name+'_'] = lines_gdf.geometry.intersection(lines_gdf.loc[line_name].geometry)

# %%
intersection_bool = pd.DataFrame({}) # boolean dataframe of whether theres an intersection

for line_name in lines_gdf.index.tolist():

    intersection_bool[line_name+'_'] = lines_gdf.geometry.intersects(lines_gdf.loc[line_name].geometry)

# %%
#to make this swifter we'll convert to numpy array
iv = intersection_table.values
ib = intersection_bool.values
np.fill_diagonal(ib,False) #set diagonals to nan

# %%
iv[~ib] = np.nan

# %%
intersection_table = pd.DataFrame(data = iv, columns= lines_gdf.index.tolist())

# %%
intersection_table['line_name'] = lines_gdf.index.tolist()
intersection_table.set_index('line_name',inplace=True)

# %%
intersection_table.line7.dropna()

# %%
intersection_table.lineAPRESdown.dropna()

# %%
intersection_table.to_pickle('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/lines_intersectionpoints.pkl')

# %%
intersection_bool = pd.DataFrame(data = ib, columns= lines_gdf.index.tolist())
intersection_bool['line_name'] = lines_gdf.index.tolist()
intersection_bool.set_index('line_name',inplace=True)
intersection_bool.line7.head()

# %%
#which lines intersect with which
intersection_bool.to_pickle('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/lines_intersects_boolean.pkl')

# %%
a,b = nearest_points(lines_mtp.loc['line7'].geometry,lines_mtp.loc['line8'].geometry)
print(a.wkt,b.wkt)
# Out:
# POINT (-380296.8 -724611.8) POINT (-381159.7 -723834.7)

# %% [markdown]
# # Using nearest_points make the same table as intersection_table but with tuples of points from the lines

# %%
listofrows = []
for line_name0 in lines_gdf.index.tolist():
    row = []
    for line_name1 in lines_gdf.index.tolist():        
        row.append( nearest_points(lines_mtp.loc[line_name0].geometry,lines_mtp.loc[line_name1].geometry) )
    listofrows.append(row)

# %%
nearest_points_table = pd.DataFrame(data=listofrows, columns = lines_gdf.index.tolist())
nearest_points_table['line_name'] = lines_gdf.index.tolist()
nearest_points_table.set_index('line_name',inplace=True)

# %%
nearest_points_table.head()
# Out:
#                                                        line7  \
# line_name
# line7      (POINT (-381564.6 -725999.7), POINT (-381564.6...
# line9      (POINT (-381065.4 -722134), POINT (-379471.7 -...
# line0      (POINT (-375351 -731659.2), POINT (-381564.6 -...
# line10     (POINT (-382482.7 -721042.4), POINT (-379506.8...
# line11     (POINT (-384405.8 -720492.8), POINT (-380261.2...
#
#                                                        line9  \
# line_name
# line7      (POINT (-379471.7 -723757.5), POINT (-381065.4...
# line9      (POINT (-380741.9 -721788.1), POINT (-380741.9...
# line0      (POINT (-374781.9 -731037.1), POINT (-382203.7...
# line10     (POINT (-382482.7 -721042.4), POINT (-381259.5...
# line11     (POINT (-384218.5 -720295), POINT (-381651.1 -...
#
#                                                        line0  \
# line_name
# line7      (POINT (-381564.6 -725999.7), POINT (-375351 -...
# line9      (POINT (-382203.7 -723326.1), POINT (-374781.9...
# line0      (POINT (-377572 -734075.1), POINT (-377572 -73...
# line10     (POINT (-383697.7 -722250.3), POINT (-374781.9...
# line11     (POINT (-384760 -720846.9), POINT (-374781.9 -...
#
#                                                       line10  \
# line_name
# line7      (POINT (-379506.8 -723793.7), POINT (-382482.7...
# line9      (POINT (-381259.5 -722307.5), POINT (-382482.7...
# line0      (POINT (-374781.9 -731037.1), POINT (-383697.7...
# line10     (POINT (-385757.3 -724442.8), POINT (-385757.3...
# line11     (POINT (-384747.3 -720833.9), POINT (-383482.1...
#
#                                                       line11  \
# line_name
# line7      (POINT (-380261.2 -724574.5), POINT (-384405.8...
# line9      (POINT (-381651.1 -722705.4), POINT (-384218.5...
# line0      (POINT (-374781.9 -731037.1), POINT (-384760 -...
# line10     (POINT (-383482.1 -722011.1), POINT (-384747.3...
# line11     (POINT (-384056.4 -720106.7), POINT (-384056.4...
#
#                                                       line12  \
# line_name
# line7      (POINT (-381103.1 -725464.4), POINT (-386882.2...
# line9      (POINT (-383950.1 -725092.2), POINT (-388050.6...
# line0      (POINT (-375841.8 -732170.2), POINT (-387395.1...
# line10     (POINT (-384951.8 -723551), POINT (-387560 -72...
# line11     (POINT (-386129.2 -722196.4), POINT (-387409.5...
#
#                                                       line13  \
# line_name
# line7      (POINT (-381075.9 -725435.5), POINT (-387797.9...
# line9      (POINT (-383790.8 -724929.7), POINT (-388879.4...
# line0      (POINT (-374781.9 -731037.1), POINT (-387797.9...
# line10     (POINT (-384456.1 -723026.1), POINT (-388300.9...
# line11     (POINT (-386325.6 -722406.3), POINT (-388879.4...
#
#                                                       line14  \
# line_name
# line7      (POINT (-381075.9 -725435.5), POINT (-389217.9...
# line9      (POINT (-382914.8 -724011.1), POINT (-389399.3...
# line0      (POINT (-374781.9 -731037.1), POINT (-389207.5...
# line10     (POINT (-384456.1 -723026.1), POINT (-389686.4...
# line11     (POINT (-385788.2 -721845.8), POINT (-389690.9...
#
#                                                        line1  \
# line_name
# line7      (POINT (-381564.6 -725999.7), POINT (-376491 -...
# line9      (POINT (-382196.6 -723318.9), POINT (-375437.3...
# line0      (POINT (-375930.6 -732263), POINT (-376855 -73...
# line10     (POINT (-383691.5 -722243.9), POINT (-375541.7...
# line11     (POINT (-384749.9 -720836.6), POINT (-375437.3...
#
#                                                      line250  ...  \
# line_name                                                     ...
# line7      (POINT (-378995.7 -723264.8), POINT (-334455 -...  ...
# line9      (POINT (-380741.9 -721788.1), POINT (-334455 -...  ...
# line0      (POINT (-374781.9 -731037.1), POINT (-334455 -...  ...
# line10     (POINT (-382482.7 -721042.4), POINT (-334455 -...  ...
# line11     (POINT (-384056.4 -720106.7), POINT (-334455 -...  ...
#
#                                                       left46  \
# line_name
# line7      (POINT (-378995.7 -723264.8), POINT (-377898 -...
# line9      (POINT (-380741.9 -721788.1), POINT (-377898 -...
# line0      (POINT (-374781.9 -731037.1), POINT (-376819.9...
# line10     (POINT (-382482.7 -721042.4), POINT (-377898 -...
# line11     (POINT (-384056.4 -720106.7), POINT (-377898 -...
#
#                                                       left79  \
# line_name
# line7      (POINT (-379013 -723281.4), POINT (-379027.1 -...
# line9      (POINT (-380741.9 -721788.1), POINT (-380734.9...
# line0      (POINT (-374781.9 -731037.1), POINT (-379027.1...
# line10     (POINT (-382482.7 -721042.4), POINT (-380747.9...
# line11     (POINT (-384056.4 -720106.7), POINT (-380747.9...
#
#                                                      left810  \
# line_name
# line7      (POINT (-379047.5 -723315.1), POINT (-379938.4...
# line9      (POINT (-380865.1 -721900.4), POINT (-380865.4...
# line0      (POINT (-374781.9 -731037.1), POINT (-379938.4...
# line10     (POINT (-382482.7 -721042.4), POINT (-382474.8...
# line11     (POINT (-384056.4 -720106.7), POINT (-382482.8...
#
#                                                    right1112  \
# line_name
# line7      (POINT (-381564.6 -725999.7), POINT (-387514.3...
# line9      (POINT (-383950.1 -725092.2), POINT (-387514.3...
# line0      (POINT (-377128.4 -733566), POINT (-387514.3 -...
# line10     (POINT (-385757.3 -724442.8), POINT (-387514.3...
# line11     (POINT (-387482 -723617.3), POINT (-387514.3 -...
#
#                                                    right1314  \
# line_name
# line7      (POINT (-381564.6 -725999.7), POINT (-391106.5...
# line9      (POINT (-383950.1 -725092.2), POINT (-391106.5...
# line0      (POINT (-377538.9 -734007.1), POINT (-391106.5...
# line10     (POINT (-385757.3 -724442.8), POINT (-391106.5...
# line11     (POINT (-387482 -723617.3), POINT (-391106.5 -...
#
#                                                      right13  \
# line_name
# line7      (POINT (-381564.6 -725999.7), POINT (-379422.6...
# line9      (POINT (-383950.1 -725092.2), POINT (-379422.6...
# line0      (POINT (-377306.6 -733755.7), POINT (-378261.1...
# line10     (POINT (-385757.3 -724442.8), POINT (-379422.6...
# line11     (POINT (-386959 -723112.4), POINT (-379422.6 -...
#
#                                                      right24  \
# line_name
# line7      (POINT (-381564.6 -725999.7), POINT (-379981.4...
# line9      (POINT (-383950.1 -725092.2), POINT (-379981.4...
# line0      (POINT (-376973.5 -733406.3), POINT (-378801.5...
# line10     (POINT (-385757.3 -724442.8), POINT (-379981.4...
# line11     (POINT (-386927.1 -723079), POINT (-379981.4 -...
#
#                                                      right68  \
# line_name
# line7      (POINT (-381564.6 -725999.7), POINT (-382001.1...
# line9      (POINT (-383855.6 -724996.7), POINT (-383017.3...
# line0      (POINT (-375853 -732181.7), POINT (-381116 -72...
# line10     (POINT (-385133.2 -723751.5), POINT (-383017.3...
# line11     (POINT (-386516.7 -722628.8), POINT (-383017.3...
#
#                                                     right910  \
# line_name
# line7      (POINT (-381564.6 -725999.7), POINT (-383945.9...
# line9      (POINT (-383937.5 -725079.8), POINT (-383945.9...
# line0      (POINT (-375945.7 -732279.5), POINT (-383945.9...
# line10     (POINT (-385757.3 -724442.8), POINT (-385759.7...
# line11     (POINT (-386992.8 -723144.6), POINT (-385801.1...
#
#                                                        line5
# line_name
# line7      (POINT (-379749.6 -724075.7), POINT (-378099.3...
# line9      (POINT (-382195.2 -723317.4), POINT (-378886.8...
# line0      (POINT (-375346 -731653.8), POINT (-379840.2 -...
# line10     (POINT (-382482.7 -721042.4), POINT (-378049.6...
# line11     (POINT (-384405.8 -720492.8), POINT (-378659 -...
#
# [5 rows x 47 columns]

# %%
# This file has the closest two points of each 2 lines 
nearest_points_table.to_pickle('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/nearest_points_table.pkl')

# %% [markdown]
# # Now run through the nearest points and get errors.
#
# ## first mark 'intersection'=True on the bed_df file

# %%
nearest_points_raw = pd.read_pickle('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/nearest_points_table.pkl')
intersection_bool = pd.read_pickle('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/lines_intersects_boolean.pkl')

# %%
print(nearest_points_raw.loc['line7','lineAPRESdown'][0].wkt,nearest_points_raw.loc['line7','lineAPRESdown'][1].wkt)
# Out:
# POINT (-380790.8 -725148.8) POINT (-380791.1 -725148.1)

# %%
#to make this swifter we'll convert to numpy array
nearp = nearest_points_raw.values
ib = intersection_bool.values

# %%
nearp[~ib] = np.nan

# %%
# This dataframe near_points_at_intersection has the closest two points of each 2 lines, just for the lines which intersect
near_points_at_intersection = pd.DataFrame(data = nearp, columns= lines_gdf.index.tolist())
near_points_at_intersection['line_name'] = lines_gdf.index.tolist()
near_points_at_intersection.set_index('line_name',inplace=True)
near_points_at_intersection.line7.dropna()
# Out:
# line_name
# lineAPRESdown    (POINT (-380791.1 -725148.1), POINT (-380790.8...
# lineupchan       (POINT (-380743.3 -725104.8), POINT (-380743.7...
# Name: line7, dtype: object

# %%
tuples_at_intersections = [] #tuples of coordinates at intersections
line_names = []
for line_name in lines_gdf.index.tolist():
    
    tuples_at_intersections.extend( near_points_at_intersection.loc[line_name].dropna().tolist()  )
    line_names.append(line_name)

# %%
tuples_of_delay = []
tuples_of_indicies = []

for tup in tuples_at_intersections:
    
    i0 = bed_gdf[bed_gdf.geometry==tup[0]].index[0]
    i1 = bed_gdf[bed_gdf.geometry==tup[1]].index[0]
    tuples_of_indicies.append( (i0,i1) )
    
    tuples_of_delay.append( (int(bed_gdf.loc[i0].DELAY),int(bed_gdf.loc[i1].DELAY) ))

# %% [markdown]
# # Now compare the delays

# %%
tuples_range = []

for tup in tuples_of_delay:
    tuples_range.append( tup[0] - tup[1] )

# %%
intersections_df = gpd.GeoDataFrame(geometry = [tup[0] for tup in tuples_at_intersections]) #just one of the two
intersections_df['delay_error'] = tuples_range

# %%
plt.figure(figsize=(12,7))
plt.hist(tuples_range, 50, density=False, facecolor='g')
plt.grid()
plt.title('Count of error in DELAY from coincidental points')
plt.xlabel('range in delay close to a point')
plt.ylabel('count')
plt.show()

# %%
# delay_at_intersections = list(sum(tuples_of_delay, ()))
# indicies_at_intersections = list(sum(tuples_of_delay, ()))

# %%
plt.figure(figsize=(25,15))
for line in bed_gdf.line_name.unique().tolist():
    plt.plot(bed_gdf[bed_gdf.line_name==line].x,bed_gdf[bed_gdf.line_name==line].y,'b:')
plt.scatter(intersections_df.geometry.x,intersections_df.geometry.y,c=intersections_df.delay_error,cmap='hsv')
plt.colorbar()
plt.grid()
plt.title('crossings which dont match up')
plt.show()

# %%
plt.figure(figsize=(25,15))
for line in bed_gdf.line_name.unique().tolist():
    plt.plot(bed_gdf[bed_gdf.line_name==line].x,bed_gdf[bed_gdf.line_name==line].y,'b:')
plt.scatter(intersections_df.geometry.x,intersections_df.geometry.y,c=intersections_df.delay_error,
            cmap='Spectral',s=400)
plt.xlim([-394000,-373000 ])
plt.ylim([-735000,-715000 ])
plt.colorbar()
plt.grid()
plt.title('crossings which dont match up')
plt.show()

# %%
plt.figure(figsize=(25,15))
for line in bed_gdf.line_name.unique().tolist():
    plt.plot(bed_gdf[bed_gdf.line_name==line].x,bed_gdf[bed_gdf.line_name==line].y,'b:')
plt.scatter(intersections_df.geometry.x,intersections_df.geometry.y,c=intersections_df.delay_error,
            cmap='Spectral',s=400)
plt.xlim([-382500,-377500 ])
plt.ylim([-730000,-722500 ])
plt.colorbar()
plt.grid()
plt.title('crossings which dont match up')
plt.show()

# %%
plt.figure(figsize=(25,15))
for line in bed_gdf.line_name.unique().tolist():
    plt.plot(bed_gdf[bed_gdf.line_name==line].x,bed_gdf[bed_gdf.line_name==line].y,'b:')
plt.scatter(intersections_df.geometry.x,intersections_df.geometry.y,c=intersections_df.delay_error,
            cmap='Spectral',s=400)
plt.xlim([-381500,-380500 ])
plt.ylim([-726000,-724000 ])
plt.colorbar()
plt.grid()
plt.title('crossings which dont match up')
plt.show()
