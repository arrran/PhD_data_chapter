# %% [markdown]
# # Check out how the channel might meander from the old radarlines to new
#
# Interpolation of old and new radarline comes from 26_RADAR_interpolate_line2line_by_distance_downchan

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import sys
import time
import datetime as dt
import pandas as pd
import geopandas as gpd
import scipy as sp
from scipy import signal
from tqdm.notebook import tqdm
import rasterio as rio
from shapely.geometry import Point, LineString, Polygon, MultiPoint
import fiona
from shapely.ops import nearest_points

# %%
# !pwd
# Out:
# /Users/home/whitefar/DATA/Jupyter/RADAR/RADAR_MAP

# %%
im_REMA_filled = im_REMA*100
# im_REMA_filled[im_REMA_filled==np.nan] = 70
im_REMA_filled[:14000,:12000] = 70

# %%
plt.figure(figsize=(18.5,15))
plt.imshow(im_REMA_filled,extent=extent_REMA,vmin=30,vmax=70, cmap='BrBG')
cb = plt.colorbar()
cb.set_label('surface elevation, m.a.s.l.')

plt.scatter(bed_gdf.x, bed_gdf.y, c=bed_gdf.bed,vmin=-700,vmax=-350,cmap='gist_rainbow')
cb2 = plt.colorbar()
cb2.set_label('ice base elevation, m.a.s.l.')
plt.xlabel('x, UTM')
plt.ylabel('y, UTM')
# basecolour_surfcontour

plt.xlim([-384000, -374800])
plt.ylim([-733300,-722000])
plt.grid()
plt.savefig('/Users/home/whitefar/ASSIGNMENTS-PUBLICATIONS-TALKS/channel_data_writeup/PLOTS/radarlines_surfcolour.png')
plt.show()

# %%
a = np.array([1,2,3,4,3])
a[a==3] = 33
a
# Out:
# array([ 1,  2, 33,  4, 33])

# %%
line35 = gpd.read_file('/Volumes/arc_04/FIELD_DATA/K8621920/RES/PROCESSED_LINES/picked_bed.shp').query('camp == "KIS2"  & line_name == "left35"')

# %%
plt.plot(line35.bed,line35.y)
plt.grid()

# %%
lineAPRESdown = gpd.read_file('/Volumes/arc_04/FIELD_DATA/K8621920/RES/PROCESSED_LINES/picked_bed.shp').query('camp == "KIS2"  & line_name == "lineAPRESdown"')
plt.plot(lineAPRESdown.bed,lineAPRESdown.y)
plt.grid()

# %% [markdown]
# # find out width of channel surf and bed

# %%
new_gpr.keys()
# Out:
# Index(['CDP', 'x', 'y', 'DELAY', 'line_name', 'surf', 'SEQnum', 'camp',
#        'time_UTC', 'ice_thickn', 'bed', 'geometry'],
#       dtype='object')

# %%
ll = {} #a dictionary of geodataframes of radarlines over KIS2, ie one gdf for each line.

for line in new_gpr[new_gpr.camp =='KIS2'].line_name.unique().tolist():
    ll[line] = new_gpr[(new_gpr.line_name==line) & (new_gpr.camp=='KIS2')].copy()
    ll[line].sort_values(by='x',inplace=True)
    ll[line].reset_index(drop=True,inplace=True)

# %%
for line_name,line in ll.items():
    plt.plot(line.surf,label=line_name)
    plt.legend()
    plt.grid()
    plt.show()

# %%
width_0 = ll['line7'].loc[0].geometry.distance(ll['line7'].loc[1000].geometry)
width_6 = ll['line6'].loc[100].geometry.distance(ll['line6'].loc[1100].geometry)
width_0 = ll['line0'].loc[450].geometry.distance(ll['line0'].loc[1300].geometry)
print('width at line7 then 6 is about',width_0,width_6, width_0)
# Out:
# width at line7 then 6 is about 2549.5080094010377 2992.419410777798 2549.5080094010377

# %%
#depth of channel 100-300m
for line_name,line in ll.items():
    plt.plot(line.ice_thickn,label=line_name)
    plt.legend()
    plt.show()

# %%
#op = original points
ice_thickn_op = np.load('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/ice_thickn_channel.npy')
points_x_op = np.load('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/points_x_channel.npy')
points_y_op = np.load('/Users/home/whitefar/DATA/FIELD_ANT_19/POST_FIELD/RADAR_MAP/points_y_channel.npy')

# %%
#width of channel
lhs =[Point(x,y) for x,y in zip(points_x_op[0,:],points_y_op[0,:])]
rhs=[Point(x,y) for x,y in zip(points_x_op[-1,:],points_y_op[-1,:])]
width = [l.distance(r) for l,r in zip(lhs,rhs)]
plt.plot(width,'x')
plt.grid()

# %%
x_new[0,:]
# Out:
# array([-381579.1       , -381562.11945716, -381543.82203319,
#        -381524.30570977, -381503.6684686 , -381482.00829134,
#        -381459.42315969, -381436.01105533, -381411.86995994,
#        -381387.09785522, -381361.79272284, -381336.05254448,
#        -381309.97530184, -381283.65897659, -381257.20155042,
#        -381230.70100502, -381204.25532206, -381177.96248324,
#        -381151.92047023, -381126.22385184, -381100.8938392 ,
#        -381075.88103194, -381051.13316628, -381026.59797843,
#        -381002.22320462, -380977.95658106, -380953.74652645,
#        -380929.56410071, -380905.40770432, -380881.27737062,
#        -380857.17313295, -380833.09502463, -380809.04307901,
#        -380785.01732941, -380761.01780917, -380737.04455162,
#        -380713.09759009, -380689.17695792, -380665.28268844,
#        -380641.41481498, -380617.57337088, -380593.75838947,
#        -380569.96990408, -380546.20794804, -380522.4725547 ,
#        -380498.76375737, -380475.0815894 , -380451.42608411,
#        -380427.79727485, -380404.19519494, -380380.61987772,
#        -380357.07135652, -380333.54966467, -380310.0548355 ,
#        -380286.58690236, -380263.14589857, -380239.73185746,
#        -380216.34481237, -380192.98479664, -380169.65184358,
#        -380146.34598655, -380123.06725887, -380099.81569387,
#        -380076.59132489, -380053.39418525, -380030.22430831,
#        -380007.08172737, -379983.96647579, -379960.87875801,
#        -379937.82235454, -379914.80443277, -379891.83229337,
#        -379868.91323699, -379846.0545643 , -379823.26357594,
#        -379800.54757259, -379777.9138549 , -379755.36972353,
#        -379732.92247913, -379710.57942238, -379688.34785392,
#        -379666.23507442, -379644.24838454, -379622.39508493,
#        -379600.68247626, -379579.11785918, -379557.70853435,
#        -379536.46180244, -379515.3849641 , -379494.48531999,
#        -379473.77017076, -379453.24681709, -379432.92255963,
#        -379412.80469904, -379392.90053597, -379373.21737109,
#        -379353.76250505, -379334.54323852, -379315.56687215,
#        -379296.84070661, -379278.37204255, -379260.16818063,
#        -379242.23553777, -379224.55810399, -379207.09620934,
#        -379189.80905323, -379172.65583511, -379155.59575442,
#        -379138.58801058, -379121.59180304, -379104.56633123,
#        -379087.47079459, -379070.26439255, -379052.90632454,
#        -379035.35579   , -379017.57508414, -378999.56366199,
#        -378981.34552087, -378962.94509348, -378944.38681249,
#        -378925.69511061, -378906.8944205 , -378888.00917485,
#        -378869.06380636, -378850.08274769, -378831.09043155,
#        -378812.11129061, -378793.16975755, -378774.29026507,
#        -378755.49724584, -378736.81513256, -378718.2683579 ,
#        -378699.88135455, -378681.67855519, -378663.68439252,
#        -378645.9232992 , -378628.41970794, -378611.19805141,
#        -378594.2827623 , -378577.69827329, -378561.46901707,
#        -378545.61942633, -378530.17393373, -378515.15696069,
#        -378500.58327988, -378486.44042889, -378472.71117412,
#        -378459.37828199, -378446.42451892, -378433.83265132,
#        -378421.5854456 , -378409.66566819, -378398.0560855 ,
#        -378386.73946394, -378375.69856992, -378364.91616988,
#        -378354.3750302 , -378344.05791733, -378333.94759766,
#        -378324.02683761, -378314.27840361, -378304.68506206,
#        -378295.22957938, -378285.89472198, -378276.66325629,
#        -378267.51794871, -378258.44156566, -378249.41687356,
#        -378240.42663881, -378231.45362785, -378222.48060708,
#        -378213.49034291, -378204.46560177, -378195.38915006,
#        -378186.24375421, -378177.01218062, -378167.67719572,
#        -378158.22156592, -378148.62805763, -378138.87943727,
#        -378128.95847125, -378118.84792599, -378108.53056791,
#        -378097.98916342, -378087.20647893, -378076.16528086,
#        -378064.84833563, -378053.23840965, -378041.31826934,
#        -378029.0706811 , -378016.47841137, -378003.52422654,
#        -377990.19089305, -377976.46117729, -377962.31784569,
#        -377947.74470681, -377932.74796068, -377917.35535588,
#        -377901.59551445, -377885.49705843, -377869.08860986,
#        -377852.39879079, -377835.45622325, -377818.28952929,
#        -377800.92733094, -377783.39825026, -377765.73090928,
#        -377747.95393004, -377730.09593459, -377712.18554497,
#        -377694.25138322, -377676.32207137, -377658.42623148,
#        -377640.59248559, -377622.84945573, -377605.22576394,
#        -377587.75003228, -377570.45088277, -377553.35693747,
#        -377536.49681842, -377519.89914765, -377503.5925472 ,
#        -377487.60563913, -377471.96704547, -377456.70538826,
#        -377441.84928954, -377427.42737136, -377413.46825576,
#        -377400.00056478, -377387.05292046, -377374.65394484,
#        -377362.83225996, -377351.61648788, -377341.03512351,
#        -377331.10099318, -377321.79633542, -377313.09985241,
#        -377304.99024635, -377297.44621944, -377290.44647386,
#        -377283.9697118 , -377277.99463547, -377272.49994705,
#        -377267.46434873, -377262.86654271, -377258.68523118,
#        -377254.89911633, -377251.48690036, -377248.42728545,
#        -377245.6989738 , -377243.28066761, -377241.15106906,
#        -377239.28888034, -377237.67280366, -377236.28154119,
#        -377235.09379514, -377234.0882677 , -377233.24366106,
#        -377232.5386774 , -377231.95201893, -377231.46238784,
#        -377231.04848632, -377230.68901656, -377230.36268075,
#        -377230.04818109, -377229.72421976, -377229.36949897,
#        -377228.9627209 , -377228.48258775, -377227.90780171,
#        -377227.21706497, -377226.38907972, -377225.40254815,
#        -377224.23617247, -377222.86865485, -377221.2786975 ,
#        -377219.44500261, -377217.34627236, -377214.96120896,
#        -377212.26851458, -377209.24689144, -377205.87504171,
#        -377202.13166759, -377197.99547127, -377193.44515495,
#        -377188.45942082, -377183.01697107, -377177.09650789,
#        -377170.67673347, -377163.73635002, -377156.25405971,
#        -377148.20856474, -377139.57856732, -377130.34276961,
#        -377120.47987383, -377109.96858216, -377098.7875968 ,
#        -377086.91561993, -377074.33135376, -377061.01350046,
#        -377046.94076224, -377032.09184129, -377016.4454398 ,
#        -376999.98025996, -376982.67500396, -376964.508374  ,
#        -376945.45907227, -376925.50580097, -376904.62726227,
#        -376882.80215839, -376860.0091915 , -376836.2270638 ,
#        -376811.43447749, -376785.61013476, -376758.73273779,
#        -376730.78098879, -376701.73358994, -376671.56924344,
#        -376640.26665147, -376607.80451624, -376574.16153993,
#        -376539.31642474, -376503.24787286, -376465.93458647,
#        -376427.35526779, -376387.48861898, -376346.31334226,
#        -376303.80813981, -376259.95171382, -376214.72276648,
#        -376168.1       ])

# %% [markdown]
# # find length of channel

# %%
mid_chan = gpd.read_file('/Volumes/arc_04/FIELD_DATA/K8621920/RES/SHARE_SHAPEFILES/interpolated_channel_mid.shp')

# %%
LineString(mid_chan.geometry.tolist()).length
# Out:
# 10056.604069366851

# %% [markdown]
# # Find minimum ice thickness location and see if it corresponds with rema bullseye

# %%
#min is at index=39

# %% [markdown]
# ## Draw 3D 'view' of channel

# %%
plt.figure(figsize=(20,10))
plt.plot(x_new[0,:],ib_new[0,:],'1')
plt.plot(x_new[10,:],ib_new[10,:],'1')
plt.plot(x_new[13,:],ib_new[13,:],'1')
plt.plot(x_new[-1,:],ib_new[-1,:],'1')
# plt.plot(x,it,'x')
plt.grid()
plt.show()

# %% [markdown]
# ## Midchan colored over bullseye

# %%
# %matplotlib qt
#rema
extent_REMA1 = [image.bounds[0],image.bounds[2],image.bounds[1],image.bounds[3]]
plt.figure(figsize=(15,15))
GyRd = plt.cm.get_cmap('RdGy').reversed()
plt.imshow(im,extent=extent_REMAdiff, vmin=-0.2,vmax=1,cmap=GyRd)
cb = plt.colorbar()
cb.set_label('rate of elevation change, m/a')

plt.scatter(x_new[10,:],y_new[10,:],c=ib_new[10,:],cmap='gist_rainbow')


plt.savefig('/Users/home/whitefar/ASSIGNMENTS-PUBLICATIONS-TALKS/channel_data_writeup/PLOTS/bullseye_n_basecontour.png')
# cb2 = plt.colorbar()
# cb2.set_label('Elevation of ice underside, m')
plt.xlim([-382000, -374800])
plt.ylim([-733300,-724000])
plt.grid()
plt.show()
