# %% [markdown]
# # Isolate and save only the cryosat lines which intersect the field site

# %% [markdown]
# ### Workflow
#
# 1. read kml:
#
# gpd.read_file()
#
# 2. convert datum
#
# .to_crs({'init' :'epsg:3031'})
#
# 3. does the line intersect field buffer
#
# 4. save interseection as shp file

# %%
import numpy as np
import zipfile

import os
import sys
import geopandas as gpd
import shapely as sp
import matplotlib.pyplot as plt
import fiona
import pyproj


fiona.supported_drivers['libkml'] = 'r'
fiona.supported_drivers['LIBKML'] = 'r'

#working_dir = '/Volumes/arc_02/REMOTE_SENSING/'
directory = "/Volumes/arc_02/REMOTE_SENSING/CRYOSAT2/GROUND_TRACKS/SHAPEFILES"

sys.path.append(os.path.abspath(directory))
sys.path.append(os.path.abspath('/Users/home/whitefar/DATA/code/'))
os.chdir(directory)

# %%
output_folder = "/Volumes/arc_02/REMOTE_SENSING/CRYOSAT2/GROUND_TRACKS/SHAPEFILES/FIELD_SITE_ANT_19"
input_file = "/Volumes/arc_02/REMOTE_SENSING/CRYOSAT2/GROUND_TRACKS/ORIGINALS/CRYOSAT2_ORBIT_SWATH_20190711_040000_20200713_110000.KML"

area_wanted_path = "/Users/home/whitefar/DATA/FIELD_ANT_19/study_area_buffer.shp"
area_wanted_gdf = gpd.read_file(area_wanted_path)

# %%
os.path.isfile(input_file)
# Out:
# True

# %%
# get list of all the paths within the kml file
cryosat_pathnames = fiona.listlayers(input_file)[1:]  #first in list is the header

# %%
def export_only_intersection(area_wanted_gdf, path_name, input_kml, output_folder):
    """
    This reads a particular path from a sublayer in a kml file, 
    then converts it to epsg3031 then checks to see if if overlaps an area
    then outputs the intersection if it does
    """
    
    path_gpd = gpd.read_file(input_file, driver='LIBKML', layer=path_name).to_crs({'init' :'epsg:3031'}) #read path and convert datum
    
    if bool(path_gpd.intersects(area_wanted_gdf)[0]) is True:
        path_gpd.intersection(area_wanted_gdf).to_file(os.path.join(output_folder,"CRYOSAT2_"+ path_name + ".shp"))
        outputted = 1
        print("written a line to ",os.path.join(output_folder, "CRYOSAT2_" + path_name + ".shp"))
    else:
        outputted = 0
        
    return outputted

# %%
num_lines = 0

for i, path_name in enumerate(cryosat_pathnames):
    
    out = export_only_intersection(area_wanted_gdf, path_name, input_file, output_folder)
    
    num_lines = num_lines + out
    
    print(i+1,"/",len(cryosat_pathnames))
    
print(num_lines)
# Out:
# 1 / 370
# 2 / 370
# 3 / 370
# 4 / 370
# 5 / 370
# 6 / 370
# 7 / 370
# 8 / 370
# 9 / 370
# 10 / 370
# 11 / 370
# 12 / 370
# 13 / 370
# 14 / 370
# 15 / 370
# 16 / 370
# 17 / 370
# 18 / 370
# 19 / 370
# 20 / 370
# 21 / 370
# written a line to  /Volumes/arc_02/REMOTE_SENSING/CRYOSAT2/GROUND_TRACKS/SHAPEFILES/FIELD_SITE_ANT_19/CRYOSAT2_2019-07-31.shp
# 22 / 370
# 23 / 370
# written a line to  /Volumes/arc_02/REMOTE_SENSING/CRYOSAT2/GROUND_TRACKS/SHAPEFILES/FIELD_SITE_ANT_19/CRYOSAT2_2019-08-02.shp
# 24 / 370
# 25 / 370
# written a line to  /Volumes/arc_02/REMOTE_SENSING/CRYOSAT2/GROUND_TRACKS/SHAPEFILES/FIELD_SITE_ANT_19/CRYOSAT2_2019-08-04.shp
# 26 / 370
# 27 / 370
# 28 / 370
# 29 / 370
# 30 / 370
# 31 / 370
# 32 / 370
# 33 / 370
# 34 / 370
# 35 / 370
# 36 / 370
# 37 / 370
# 38 / 370
# 39 / 370
# 40 / 370
# 41 / 370
# 42 / 370
# 43 / 370
# 44 / 370
# 45 / 370
# 46 / 370
# 47 / 370
# 48 / 370
# 49 / 370
# 50 / 370
# 51 / 370
# 52 / 370
# 53 / 370
# 54 / 370
# 55 / 370
# 56 / 370
# 57 / 370
# 58 / 370
# 59 / 370
# 60 / 370
# 61 / 370
# 62 / 370
# 63 / 370
# 64 / 370
# 65 / 370
# 66 / 370
# 67 / 370
# 68 / 370
# 69 / 370
# 70 / 370
# 71 / 370
# 72 / 370
# 73 / 370
# 74 / 370
# 75 / 370
# 76 / 370
# 77 / 370
# 78 / 370
# 79 / 370
# 80 / 370
# 81 / 370
# 82 / 370
# 83 / 370
# 84 / 370
# 85 / 370
# 86 / 370
# 87 / 370
# 88 / 370
# 89 / 370
# 90 / 370
# 91 / 370
# 92 / 370
# 93 / 370
# 94 / 370
# 95 / 370
# 96 / 370
# 97 / 370
# 98 / 370
# 99 / 370
# 100 / 370
# 101 / 370
# 102 / 370
# 103 / 370
# 104 / 370
# 105 / 370
# 106 / 370
# 107 / 370
# 108 / 370
# 109 / 370
# 110 / 370
# 111 / 370
# 112 / 370
# 113 / 370
# 114 / 370
# 115 / 370
# 116 / 370
# 117 / 370
# 118 / 370
# 119 / 370
# 120 / 370
# 121 / 370
# 122 / 370
# 123 / 370
# 124 / 370
# 125 / 370
# 126 / 370
# 127 / 370
# 128 / 370
# 129 / 370
# 130 / 370
# 131 / 370
# 132 / 370
# 133 / 370
# 134 / 370
# 135 / 370
# 136 / 370
# 137 / 370
# 138 / 370
# 139 / 370
# 140 / 370
# 141 / 370
# 142 / 370
# 143 / 370
# 144 / 370
# 145 / 370
# 146 / 370
# 147 / 370
# 148 / 370
# 149 / 370
# 150 / 370
# 151 / 370
# 152 / 370
# 153 / 370
# 154 / 370
# 155 / 370
# 156 / 370
# 157 / 370
# 158 / 370
# 159 / 370
# 160 / 370
# 161 / 370
# 162 / 370
# 163 / 370
# 164 / 370
# 165 / 370
# 166 / 370
# 167 / 370
# 168 / 370
# 169 / 370
# 170 / 370
# 171 / 370
# 172 / 370
# 173 / 370
# 174 / 370
# 175 / 370
# 176 / 370
# 177 / 370
# 178 / 370
# 179 / 370
# 180 / 370
# 181 / 370
# 182 / 370
# 183 / 370
# 184 / 370
# 185 / 370
# 186 / 370
# 187 / 370
# 188 / 370
# 189 / 370
# 190 / 370
# 191 / 370
# 192 / 370
# 193 / 370
# 194 / 370
# 195 / 370
# 196 / 370
# 197 / 370
# 198 / 370
# 199 / 370
# 200 / 370
# 201 / 370
# 202 / 370
# 203 / 370
# 204 / 370
# 205 / 370
# 206 / 370
# 207 / 370
# 208 / 370
# 209 / 370
# 210 / 370
# 211 / 370
# 212 / 370
# 213 / 370
# 214 / 370
# 215 / 370
# 216 / 370
# 217 / 370
# 218 / 370
# 219 / 370
# 220 / 370
# 221 / 370
# 222 / 370
# 223 / 370
# 224 / 370
# 225 / 370
# 226 / 370
# 227 / 370
# 228 / 370
# 229 / 370
# 230 / 370
# 231 / 370
# 232 / 370
# 233 / 370
# 234 / 370
# 235 / 370
# 236 / 370
# 237 / 370
# 238 / 370
# 239 / 370
# 240 / 370
# 241 / 370
# 242 / 370
# 243 / 370
# 244 / 370
# 245 / 370
# 246 / 370
# 247 / 370
# 248 / 370
# 249 / 370

# %%
# Out:
# False

# %%
cryosat2_tracks_gdf = gpd.read_file(input_file)
fiona.open()
